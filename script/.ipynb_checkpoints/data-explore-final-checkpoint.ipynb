# %%
import scipy
import utils as ut
import pandas as pd
import seaborn as sns
from scipy.stats import ttest_ind
from datetime import datetime
import pytz
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.cluster import KMeans
from scipy import stats
from sklearn.preprocessing import StandardScaler

# %%
stocks = ut.get_df('../data/stocks-prepared-to-analyze.csv')
tweets = ut.get_df('../data/tweets-prepared-to-analyze.csv')
df = pd.merge(tweets, stocks, on='Date')
df.drop(columns=['Unnamed: 0'], inplace=True)
# 1 -> zvyseni, -1 -> snizeni
df['net_close_effect'] = df['Close_diff_%'].apply(lambda x: 1 if x >= 0 else -1)
df
# Out:
#             Date             to  \
# 0     2012-02-01            NaN
# 1     2012-02-01            NaN
# 2     2012-01-31            NaN
# 3     2012-01-27            NaN
# 4     2012-01-27            NaN
# ...          ...            ...
# 6536  2020-04-02       elonmusk
# 6537  2020-04-02        flcnhvy
# 6538  2020-04-02       elonmusk
# 6539  2020-04-02  28delayslater
# 6540  2020-04-02    NuovaRealta
#
#                                                    text  mentions_c  \
# 0     Just test-fired the Superdraco rocket engine. ...           0
# 1     Um, while awesome in its own way, that was not...           0
# 2     The SpaceX theme song by Total Ghost is just t...           0
# 3     The Model X unveiling will be webcast live on ...           0
# 4     Beautiful picture of Earth from the new NASA s...           0
# ...                                                 ...         ...
# 6536  Weird that so many troll/bot accounts were act...           0
# 6537  Yeah, very important to provide C/BiPAP device...           0
# 6538  Invasive ventilators are for worst case patien...           0
# 6539  Exactly. Moreover, all hospitals were given ex...           0
# 6540                       Will call when we reach Mars           0
#
#       hashtags_c  day_of_week  positive  negative  neutral  closely_related  \
# 0              0            2         0         0        1                0
# 1              0            2         1         0        0                0
# 2              0            1         1         0        0                0
# 3              0            4         1         0        0                1
# 4              0            4         1         0        0                1
# ...          ...          ...       ...       ...      ...              ...
# 6536           0            3         0         1        0                0
# 6537           0            3         1         0        0                0
# 6538           0            3         0         1        0                0
# 6539           0            3         1         0        0                0
# 6540           0            3         0         0        1                0
#
#       ...  url_news  url_video  polarity  subjectivity  time_of_day     Close  \
# 0     ...         0          0  0.266667      0.350000     7.500000  0.001108
# 1     ...         0          0  0.266667      0.350000     7.500000  0.001108
# 2     ...         0          1  0.350000      0.675000    11.000000  0.001025
# 3     ...         0          0  0.394318      0.696970    18.000000  0.001067
# 4     ...         0          0  0.394318      0.696970    18.000000  0.001067
# ...   ...       ...        ...       ...           ...          ...       ...
# 6536  ...         0          0  0.115595      0.400952    16.714286  0.070458
# 6537  ...         0          0  0.115595      0.400952    16.714286  0.070458
# 6538  ...         0          0  0.115595      0.400952    16.714286  0.070458
# 6539  ...         0          0  0.115595      0.400952    16.714286  0.070458
# 6540  ...         0          0  0.115595      0.400952    16.714286  0.070458
#
#         Volume  Close_diff  Close_diff_%  net_close_effect
# 0     0.002613    0.000083      0.081210                 1
# 1     0.002613    0.000083      0.081210                 1
# 2     0.009765   -0.000082     -0.073746                -1
# 3     0.006331    0.000064      0.063415                 1
# 4     0.006331    0.000064      0.063415                 1
# ...        ...         ...           ...               ...
# 6536  0.321814   -0.004422     -0.059049                -1
# 6537  0.321814   -0.004422     -0.059049                -1
# 6538  0.321814   -0.004422     -0.059049                -1
# 6539  0.321814   -0.004422     -0.059049                -1
# 6540  0.321814   -0.004422     -0.059049                -1
#
# [6541 rows x 24 columns]

# %% [markdown]
# ## Prev price

# %%
def find_prev(row):
    row_idx = row.name
    prev_row = df.iloc[row_idx - 1]
    if(row_idx <= 0):
            return 0
    while prev_row['Date'] == row['Date']:
        row_idx -= 1
        if(row_idx <= 0):
            return 0
        prev_row = df.iloc[row_idx - 1]
    return prev_row['Close']

df['prev_close'] = df.apply(find_prev, axis=1)

df['to_c'] = df['to'].notnull()
df['to_c'] = df['to_c'].astype(int)
df
# Out:
#             Date             to  \
# 0     2012-02-01            NaN
# 1     2012-02-01            NaN
# 2     2012-01-31            NaN
# 3     2012-01-27            NaN
# 4     2012-01-27            NaN
# ...          ...            ...
# 6536  2020-04-02       elonmusk
# 6537  2020-04-02        flcnhvy
# 6538  2020-04-02       elonmusk
# 6539  2020-04-02  28delayslater
# 6540  2020-04-02    NuovaRealta
#
#                                                    text  mentions_c  \
# 0     Just test-fired the Superdraco rocket engine. ...           0
# 1     Um, while awesome in its own way, that was not...           0
# 2     The SpaceX theme song by Total Ghost is just t...           0
# 3     The Model X unveiling will be webcast live on ...           0
# 4     Beautiful picture of Earth from the new NASA s...           0
# ...                                                 ...         ...
# 6536  Weird that so many troll/bot accounts were act...           0
# 6537  Yeah, very important to provide C/BiPAP device...           0
# 6538  Invasive ventilators are for worst case patien...           0
# 6539  Exactly. Moreover, all hospitals were given ex...           0
# 6540                       Will call when we reach Mars           0
#
#       hashtags_c  day_of_week  positive  negative  neutral  closely_related  \
# 0              0            2         0         0        1                0
# 1              0            2         1         0        0                0
# 2              0            1         1         0        0                0
# 3              0            4         1         0        0                1
# 4              0            4         1         0        0                1
# ...          ...          ...       ...       ...      ...              ...
# 6536           0            3         0         1        0                0
# 6537           0            3         1         0        0                0
# 6538           0            3         0         1        0                0
# 6539           0            3         1         0        0                0
# 6540           0            3         0         0        1                0
#
#       ...  polarity  subjectivity  time_of_day     Close    Volume  \
# 0     ...  0.266667      0.350000     7.500000  0.001108  0.002613
# 1     ...  0.266667      0.350000     7.500000  0.001108  0.002613
# 2     ...  0.350000      0.675000    11.000000  0.001025  0.009765
# 3     ...  0.394318      0.696970    18.000000  0.001067  0.006331
# 4     ...  0.394318      0.696970    18.000000  0.001067  0.006331
# ...   ...       ...           ...          ...       ...       ...
# 6536  ...  0.115595      0.400952    16.714286  0.070458  0.321814
# 6537  ...  0.115595      0.400952    16.714286  0.070458  0.321814
# 6538  ...  0.115595      0.400952    16.714286  0.070458  0.321814
# 6539  ...  0.115595      0.400952    16.714286  0.070458  0.321814
# 6540  ...  0.115595      0.400952    16.714286  0.070458  0.321814
#
#       Close_diff  Close_diff_%  net_close_effect  prev_close  to_c
# 0       0.000083      0.081210                 1    0.000000     0
# 1       0.000083      0.081210                 1    0.000000     0
# 2      -0.000082     -0.073746                -1    0.001108     0
# 3       0.000064      0.063415                 1    0.001025     0
# 4       0.000064      0.063415                 1    0.001025     0
# ...          ...           ...               ...         ...   ...
# 6536   -0.004422     -0.059049                -1    0.074627     1
# 6537   -0.004422     -0.059049                -1    0.074627     1
# 6538   -0.004422     -0.059049                -1    0.074627     1
# 6539   -0.004422     -0.059049                -1    0.074627     1
# 6540   -0.004422     -0.059049                -1    0.074627     1
#
# [6541 rows x 26 columns]

# %%
df.index = df['Date']
df.drop(columns=['Date'], inplace=True)
correlation_matrix = df.iloc[::].corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)
plt.subplots(figsize=(20,15))
sns.heatmap(correlation_matrix, cmap=cmap, vmax=1, center=0, vmin=-1,
            square=True, linewidths=.5,  annot=True, fmt=".2f")
df
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_29556\1118246186.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.iloc[::].corr()
#                        to                                               text  \
# Date
# 2012-02-01            NaN  Just test-fired the Superdraco rocket engine. ...
# 2012-02-01            NaN  Um, while awesome in its own way, that was not...
# 2012-01-31            NaN  The SpaceX theme song by Total Ghost is just t...
# 2012-01-27            NaN  The Model X unveiling will be webcast live on ...
# 2012-01-27            NaN  Beautiful picture of Earth from the new NASA s...
# ...                   ...                                                ...
# 2020-04-02       elonmusk  Weird that so many troll/bot accounts were act...
# 2020-04-02        flcnhvy  Yeah, very important to provide C/BiPAP device...
# 2020-04-02       elonmusk  Invasive ventilators are for worst case patien...
# 2020-04-02  28delayslater  Exactly. Moreover, all hospitals were given ex...
# 2020-04-02    NuovaRealta                       Will call when we reach Mars
#
#             mentions_c  hashtags_c  day_of_week  positive  negative  neutral  \
# Date
# 2012-02-01           0           0            2         0         0        1
# 2012-02-01           0           0            2         1         0        0
# 2012-01-31           0           0            1         1         0        0
# 2012-01-27           0           0            4         1         0        0
# 2012-01-27           0           0            4         1         0        0
# ...                ...         ...          ...       ...       ...      ...
# 2020-04-02           0           0            3         0         1        0
# 2020-04-02           0           0            3         1         0        0
# 2020-04-02           0           0            3         0         1        0
# 2020-04-02           0           0            3         1         0        0
# 2020-04-02           0           0            3         0         0        1
#
#             closely_related  retweets  ...  polarity  subjectivity  \
# Date                                   ...
# 2012-02-01                0        68  ...  0.266667      0.350000
# 2012-02-01                0        68  ...  0.266667      0.350000
# 2012-01-31                0        32  ...  0.350000      0.675000
# 2012-01-27                1       211  ...  0.394318      0.696970
# 2012-01-27                1       211  ...  0.394318      0.696970
# ...                     ...       ...  ...       ...           ...
# 2020-04-02                0      3876  ...  0.115595      0.400952
# 2020-04-02                0      3876  ...  0.115595      0.400952
# 2020-04-02                0      3876  ...  0.115595      0.400952
# 2020-04-02                0      3876  ...  0.115595      0.400952
# 2020-04-02                0      3876  ...  0.115595      0.400952
#
#             time_of_day     Close    Volume  Close_diff  Close_diff_%  \
# Date
# 2012-02-01     7.500000  0.001108  0.002613    0.000083      0.081210
# 2012-02-01     7.500000  0.001108  0.002613    0.000083      0.081210
# 2012-01-31    11.000000  0.001025  0.009765   -0.000082     -0.073746
# 2012-01-27    18.000000  0.001067  0.006331    0.000064      0.063415
# 2012-01-27    18.000000  0.001067  0.006331    0.000064      0.063415
# ...                 ...       ...       ...         ...           ...
# 2020-04-02    16.714286  0.070458  0.321814   -0.004422     -0.059049
# 2020-04-02    16.714286  0.070458  0.321814   -0.004422     -0.059049
# 2020-04-02    16.714286  0.070458  0.321814   -0.004422     -0.059049
# 2020-04-02    16.714286  0.070458  0.321814   -0.004422     -0.059049
# 2020-04-02    16.714286  0.070458  0.321814   -0.004422     -0.059049
#
#             net_close_effect  prev_close  to_c
# Date
# 2012-02-01                 1    0.000000     0
# 2012-02-01                 1    0.000000     0
# 2012-01-31                -1    0.001108     0
# 2012-01-27                 1    0.001025     0
# 2012-01-27                 1    0.001025     0
# ...                      ...         ...   ...
# 2020-04-02                -1    0.074627     1
# 2020-04-02                -1    0.074627     1
# 2020-04-02                -1    0.074627     1
# 2020-04-02                -1    0.074627     1
# 2020-04-02                -1    0.074627     1
#
# [6541 rows x 25 columns]

# %%
correlation_matrix = df.corr(method='spearman')
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='viridis', annot=True, cbar=True, fmt=".1f", linewidths=0.5)
plt.title("Spearman Correlation Matrix")
plt.show()
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_29556\3364463169.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='spearman')

# %% [markdown]
# # Provedeme analyzu staticke vyznamnosti.

# %%
import pandas as pd
from scipy.stats import spearmanr

data = df[['Close', 'Close_diff','Volume', 'net_close_effect']]
data2 = df[['neutral', 'positive', 'negative', 'retweets', 'hashtags_c', 'mentions_c', 'day_of_week', 'url_news', 'url_video',
           'other_related', 'tesla_related', 'closely_related', 'money_related', 'time_of_day', 'prev_close', 'to_c']]

alpha = 0.05


def get_pvalue(x, y):
    _, p_value = spearmanr(x, y)
    return p_value

p_values = pd.DataFrame(columns=data.columns, index=data.columns)


for col1 in data2.columns:
    for col2 in data.columns:
        p_values.loc[col1, col2] = get_pvalue(data2[col1], data[col2])

filtered_p_values = p_values[p_values < 0.05]

plt.figure(figsize=(10, 8))
sns.heatmap(filtered_p_values.astype(float), cmap='viridis', annot=False, cbar=True, fmt=".3f", linewidths=0.5)
plt.title("Correlation  p-values ")
plt.show()

# %%
sns.pairplot(df[['polarity', 'subjectivity', 'net_close_effect']], hue='net_close_effect', size=5, plot_kws={"s": 20})
plt.show()
# Out:
# C:\Program Files\Python311\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6541 entries, 2012-02-01 to 2020-04-02
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   to                4640 non-null   object
#  1   text              6480 non-null   object
#  2   mentions_c        6541 non-null   int64
#  3   hashtags_c        6541 non-null   int64
#  4   day_of_week       6541 non-null   int64
#  5   positive          6541 non-null   int64
#  6   negative          6541 non-null   int64
#  7   neutral           6541 non-null   int64
#  8   closely_related   6541 non-null   int64
#  9   retweets          6541 non-null   int64
#  10  money_related     6541 non-null   int64
#  11  other_related     6541 non-null   int64
#  12  tesla_related     6541 non-null   int64
#  13  url_news          6541 non-null   int64
#  14  url_video         6541 non-null   int64
#  15  polarity          6541 non-null   float64
#  16  subjectivity      6541 non-null   float64
#  17  time_of_day       6541 non-null   float64
#  18  Close             6541 non-null   float64
#  19  Volume            6541 non-null   float64
#  20  Close_diff        6541 non-null   float64
#  21  Close_diff_%      6541 non-null   float64
#  22  net_close_effect  6541 non-null   int64
#  23  prev_close        6541 non-null   float64
#  24  to_c              6541 non-null   int32
# dtypes: float64(8), int32(1), int64(14), object(2)
# memory usage: 1.5+ MB

# %%
#Bez dneska
n_days = 1
df_mean = df.rolling(window=n_days+1).mean().shift()
df_sum = df.rolling(window=n_days+1).sum().shift()
df['neutral_n_d'] = df_sum['neutral']
df['positive_n_d'] = df_sum['positive']
df['negative_n_d'] = df_sum['negative']
df['url_news_n_d'] = df_sum['url_news']
df['closely_related_n_d'] = df_sum['closely_related']
df['other_related_n_d'] = df_sum['other_related']
df['money_related_n_d'] =  df_sum['money_related']
df['volume_n_d']= df_mean['Volume']
df['tesla_related_n_d'] = df_sum['tesla_related']
df['hashtags_c_n_d'] = df_sum['hashtags_c']
df['mentions_c_n_d'] = df_sum['mentions_c']
df['retweets_n_d'] = df_sum['retweets']
df['prev_close_n'] = df_mean['prev_close']
df['close_n_d'] = df_mean['Close']
df['polarity_n_d'] = df_mean['polarity']
df['subjectivity_n_d'] = df_mean['subjectivity']
df['to_c_n_d'] = df_sum['to_c']
df.fillna(0, inplace=True)
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_29556\86314848.py:3: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['text', 'to'], dtype='object')
#   df_mean = df.rolling(window=n_days+1).mean().shift()
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_29556\86314848.py:4: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['text', 'to'], dtype='object')
#   df_sum = df.rolling(window=n_days+1).sum().shift()

# %% [markdown]
# ## Linear regression

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import chi2
# Importing libraries
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from statsmodels.compat import lzip
import statsmodels.stats.api as sms

import numpy as np

results = None

def weighted_regression(X):
    global results
    
    y = df['Close']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    X_train = sm.add_constant(X_train)  # Добавляем константный столбец для интерцепта
    X_test = sm.add_constant(X_test)

    # Создание модели
    model = sm.WLS(y_train, X_train)

    # Оценка модели
    results = model.fit()
 
    y_pred = results.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print("Mean Squared Error (MSE):", mse)
    print("R-squared (R2):", r2)
    
    plt.scatter(y_test, y_pred, c='b')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
    plt.xlabel('Porovnani Skutecne hodnoty a Predpokladane hodnoty')
    plt.ylabel('Predpokladane hodnoty')
    plt.title('Skutecne hodnoty')
    plt.show()
    
   # Контроль гомоскедастичности модели
    names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
    residuals = y_test - y_pred
    residuals_squared = residuals**2
    test_result = sms.het_breuschpagan(results.resid, results.model.exog)
    temp = lzip(names, test_result)
 
    if(temp[1][1] < 0.01):
         print('Model is heteroscedastic; p-value = ',temp[1][1])
    else:
        print('Model is homoscedastic; p-value = ',temp[1][1])
    
    

    # График остатков
    plt.scatter(y_pred, residuals)
    plt.axhline(0, color='red', linestyle='--')
    plt.xlabel('Predpokladane hodnoty')
    plt.ylabel('Zbytky')
    plt.title('Graf zbytku')
    plt.show()
    
    return results

# %%
# bez metrik tohoto dne
weighted_regression(df[['neutral_n_d','positive_n_d','negative_n_d', 'url_news_n_d', 'closely_related_n_d', 'other_related_n_d',
            'money_related_n_d', 'tesla_related_n_d', 'hashtags_c_n_d', 'mentions_c_n_d', 'retweets_n_d', 'close_n_d',
            'polarity_n_d', 'subjectivity_n_d', 'to_c_n_d']])
# Out:
# Mean Squared Error (MSE): 2.3637057498434664e-06
# R-squared (R2): 0.9962928293231128
# Model is heteroscedastic; p-value =  0.003137854731678848

# %%
# jen s metriky toho dne
weighted_regression(df[['positive', 'negative', 'neutral', 'mentions_c', 'Volume', 'retweets', 'other_related', 'tesla_related',
        'money_related', 'to_c', 'closely_related', 'url_news', 'url_video', 'hashtags_c', 'mentions_c', 'prev_close', 'Volume']])
# Out:
# Mean Squared Error (MSE): 1.6179886510896873e-05
# R-squared (R2): 0.9746239138130744
# Model is heteroscedastic; p-value =  1.8135629466062703e-23

# %%
# s metriky tohoto dne
X = df[['positive', 'negative', 'neutral', 'mentions_c', 'Volume', 'retweets', 'other_related', 'tesla_related',
        'money_related', 'to_c', 'closely_related', 'url_news', 'url_video', 'hashtags_c', 'mentions_c','prev_close',
        'neutral_n_d', 'positive_n_d', 'negative_n_d', 'url_news_n_d', 'closely_related_n_d', 'other_related_n_d',
        'money_related_n_d', 'tesla_related_n_d', 'hashtags_c_n_d', 'mentions_c_n_d', 'retweets_n_d', 'close_n_d',
        'polarity_n_d', 'subjectivity_n_d', 'to_c_n_d']]
weighted_regression(X)
# Out:
# Mean Squared Error (MSE): 2.3666019015314907e-06
# R-squared (R2): 0.9962882870789632
# Model is homoscedastic; p-value =  0.014344944786167671

# %%
def denormalize_data_frame(df, original_df):
    return df * (original_df.max() - original_df.min()) + original_df.min()
df['Close'] = denormalize_data_frame(df['Close'], df['Close'])
preds = results.predict(df[['Close','positive', 'negative', 'neutral', 'mentions_c', 'Volume', 'retweets', 'other_related', 'tesla_related',
        'money_related', 'to_c', 'closely_related', 'url_news', 'url_video', 'hashtags_c', 'mentions_c','prev_close',
        'neutral_n_d', 'positive_n_d', 'negative_n_d', 'url_news_n_d', 'closely_related_n_d', 'other_related_n_d',
        'money_related_n_d', 'tesla_related_n_d', 'hashtags_c_n_d', 'mentions_c_n_d', 'retweets_n_d', 'close_n_d',
        'polarity_n_d', 'subjectivity_n_d', 'to_c_n_d']])
print(preds)
# Out:
# Date
# 2012-02-01   -0.000101
# 2012-02-01   -0.000021
# 2012-01-31    0.001070
# 2012-01-27    0.001221
# 2012-01-27    0.001278
#                 ...
# 2020-04-02    0.070188
# 2020-04-02    0.070230
# 2020-04-02    0.070130
# 2020-04-02    0.070221
# 2020-04-02    0.070140
# Length: 6541, dtype: float64

# %% [markdown]
# ### Pri pridani metrik tohoto dne se model stava hoteroscedastickym.

# %% [markdown]
# ## Klasterizace (cena, polarita - v korelaci neutralni nejvic zvysuje cenu). Chceme vedet distribuci klasteru s tweety, ktere zvysily cenu.

# %%
df_filtered = df[df['net_close_effect'] == 1]
selected = df_filtered[['polarity_n_d', 'Close']]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(selected)
X = selected

n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(scaled_features)
labels = kmeans.labels_

plt.scatter(selected['polarity_n_d'],selected['Close'], c=labels, cmap='viridis')
plt.xlabel('polarity')
plt.ylabel('Close')
plt.title('Clustering')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# C:\Program Files\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Kazdy bod 1 tweet.

# %% [markdown]
# ## Je nutne provest analyzu vlivu tweetu na akci dalsi n dni. (Mozna nemela vliv inhned)
# ### vezmeme n = 5
